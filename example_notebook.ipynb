# %%
from calcium_signal import CalciumSignal
import numpy as np
import matplotlib.pyplot as plt
import os

path = 'Examples/CaSignal-20231009d10-4x-3zt-MaxIP_Alexa 488 antibody.mat'

signal = CalciumSignal(path)

# %%
signal.plot_mask(link=True, peak_only=True, mask=True, save =None)

# %%
signal.plot_center(peak_only=True, show=True, save=None)

# %%
signal.plot_heat(annot=False, peak_only=True, show=True, save=None)
# Out:
# 0.05236836009019496
